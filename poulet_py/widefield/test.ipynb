# %%
from analysis import WidefieldAnalysis
from pathlib import Path

# %%
fps = 20
windows = {
    "5-6s": (5 * fps, 6 * fps),
    "6-7s": (6 * fps, 7 * fps),
}

wf = WidefieldAnalysis(
    Path(
        r"Y:\Projects\widefield_pic_gp4_3_tst\data\analyzed\JPCM-07989\250627_leica\repetition_sound\avg_windows500minus_250627_155310_to_250627_155740"
    )
)

wf.process_dff_windows(
    windows=windows,
    average =  False,
    dff_filename= 'average_trials.npy',
    vmin = 0,
    vmax = 0.1
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 7
#       1 fps = 20
#       2 windows = {
#       3     "5-6s": (5 * fps, 6 * fps),
#       4     "6-7s": (6 * fps, 7 * fps),
#       5 }
# ----> 7 wf = WidefieldAnalysis(
#       8     Path(
#       9         r"Y:\Projects\widefield_pic_gp4_3_tst\data\analyzed\JPCM-07989\250627_leica\repetition_sound\avg_windows500minus_250627_155310_to_250627_155740"
#      10     )
#      11 )
#      13 wf.process_dff_windows(
#      14     windows=windows,
#      15     average =  False,
#    (...)     18     vmax = 0.1
#      19 )
#
# File x:\Projects\poulet_py\poulet_py\widefield\analysis.py:82, in WidefieldAnalysis.__init__(self, trial_path)
#      79 self.condition: dict[str, Any] | None = None
#      80 self.roi: dict[str, Any] | None = None
# ---> 82 self._validate()
# ...
