# %%
from pathlib import Path

from analysis import WidefieldAnalysis

trial_path = Path(
    r"Y:\Projects\widefield_pic_gp4_3_tst\data\raw\JPCM-07991\250818_leica\22_42_interleaved\250818_160439"
)
wf = WidefieldAnalysis(trial_path)
wf.load_data()
# Out:
# INFO     Initialized WidefieldAnalysis for: 250818_160439                                            ]8;id=381683;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=373131;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#84\84]8;;\
# INFO     Loading imaging data from: recording.tiff                                                  ]8;id=412258;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=708031;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#127\127]8;;\
# INFO     Loaded imaging stack: (300, 1024, 1024)                                                    ]8;id=745180;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=483287;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#129\129]8;;\
# INFO     Loading green reference from: green.tiff                                                   ]8;id=567485;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=757509;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#141\141]8;;\
# INFO     Loaded green reference: (2048, 2048)                                                       ]8;id=945779;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=839653;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#145\145]8;;\
# INFO     Loaded timestamps: 300 rows                                                                ]8;id=998831;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=855796;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#160\160]8;;\
# INFO     Loaded 5 sensor traces from H5                                                             ]8;id=517210;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=898941;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#181\181]8;;\
# INFO     ============================================================                               ]8;id=712996;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=508467;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#187\187]8;;\
# INFO     Trial: 250818_160439                                                                       ]8;id=281359;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=717994;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#188\188]8;;\
# INFO     ============================================================                               ]8;id=301938;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=928808;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#189\189]8;;\
# INFO     Imaging data:                                                                              ]8;id=709937;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=386971;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#193\193]8;;\
# INFO       Shape: (300, 1024, 1024)                                                                 ]8;id=424298;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=285112;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#194\194]8;;\
# INFO       Frames: 300                                                                              ]8;id=654406;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=354816;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#195\195]8;;\
# INFO       Resolution: 1024 x 1024                                                                  ]8;id=569534;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=915663;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#196\196]8;;\
# INFO       Dtype: uint16                                                                            ]8;id=340625;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=346328;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#197\197]8;;\
# INFO       Value range: [344, 2700]                                                                 ]8;id=747044;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=356864;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#198\198]8;;\
# INFO       Memory: 600.0 MB                                                                         ]8;id=707023;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=321220;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#200\200]8;;\
# INFO     Timestamps:                                                                                ]8;id=552898;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=282061;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#203\203]8;;\
# INFO       Rows: 300                                                                                ]8;id=599184;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=755377;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#204\204]8;;\
# INFO       Columns: ['page', 'buffer_idx', 'framestamp', 'sec', 'microsec']                         ]8;id=973712;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=249308;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#205\205]8;;\
# INFO     Sensor data:                                                                               ]8;id=744350;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=584443;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#208\208]8;;\
# INFO       data/in/body_temperature: shape=(15000,), sr=1000 Hz                                     ]8;id=121588;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=423453;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#212\212]8;;\
# INFO       data/in/camera: shape=(15000,), sr=1000 Hz                                               ]8;id=352864;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=32043;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#212\212]8;;\
# INFO       data/in/temperature: shape=(15000,), sr=1000 Hz                                          ]8;id=766812;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=270428;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#212\212]8;;\
# INFO       data/out/camera: shape=(15000,), sr=1000 Hz                                              ]8;id=385891;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=561272;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#212\212]8;;\
# INFO       data/out/temperature: shape=(1500000,), sr=100000 Hz                                     ]8;id=995434;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=660367;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#212\212]8;;\
# INFO     Metadata:                                                                                  ]8;id=487345;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=724320;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#218\218]8;;\
# INFO       Mouse: JPCM-07990                                                                        ]8;id=587937;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=953860;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#219\219]8;;\
# INFO       Protocol: temperature_short                                                              ]8;id=375649;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=323631;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#220\220]8;;\
# INFO       Comment: temp 32-16.0, 2 sec, 1 times                                                    ]8;id=33859;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=182565;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#222\222]8;;\
# INFO     ============================================================                               ]8;id=513573;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=206317;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#224\224]8;;\

# %%
fps = 20
windows = {
    "5-6s": (5 * fps, 6 * fps),
    "6-7s": (6 * fps, 7 * fps),
}

wf = WidefieldAnalysis(
    Path(
        r"Y:\Projects\widefield_pic_gp4_3_tst\data\raw\JPCM-07991\250818_leica\22_42_interleaved\250818_160439"
    )
)

wf.process_dff_windows(
    windows=windows,
    fps=fps,
)
# Out:
# INFO     Initialized WidefieldAnalysis for: 250818_160439                                            ]8;id=743707;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py\analysis.py]8;;\:]8;id=191048;file://x:\Projects\poulet_py\poulet_py\widefield\analysis.py#84\84]8;;\
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 11
#       2 windows = {
#       3     "5-6s": (5 * fps, 6 * fps),
#       4     "6-7s": (6 * fps, 7 * fps),
#       5 }
#       7 wf = WidefieldAnalysis(
#       8     Path(r"Y:\Projects\widefield_pic_gp4_3_tst\data\raw\JPCM-07991\250818_leica\22_42_interleaved\250818_160439")
#       9 )
# ---> 11 wf.process_dff_windows(
#      12     session_id= '250818_leica',
#      13     protocol_name='22_42_interleaved',
#      14     trial_start = '250818_160439',
#      15     windows=windows,
#      16     fps=fps,
#      17 )
#
# File x:\Projects\poulet_py\poulet_py\widefield\analysis.py:1402, in process_dff_windows(dataset_id, session_id, protocol_name, trial_start, windows, trial_end, fps, base_processed, base_analyzed, versions, vmin, vmax, colors)
#    1400     # Single trial
#    1401     all_trials = [trial_base / trial_start]
# -> 1402     LOGGER.info(f"Single-trial mode: '{trial_start}' under {trial_base}")
#    1403 else:
#    1404     # Trial range
#
# TypeError: unsupported operand type(s) for /: 'WindowsPath' and 'WidefieldAnalysis'
