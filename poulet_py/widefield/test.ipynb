# %%
from pathlib import Path

from analysis import WidefieldAnalysis

trial_path = Path(
    r"Y:\Projects\widefield_pic_gp4_3_tst\data\raw\JPCM-07991\250818_leica\22_42_interleaved\250818_160439"
)
wf = WidefieldAnalysis(trial_path)
wf.load_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pathlib import Path
# ----> 2 from analysis import WidefieldAnalysis
#       4 trial_path = Path(r"Y:\Projects\widefield_pic_gp4_3_tst\data\raw\JPCM-07991\250818_leica\22_42_interleaved\250818_160439")
#       5 wf = WidefieldAnalysis(trial_path)
#
# ModuleNotFoundError: No module named 'analysis'
